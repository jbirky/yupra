# %%
import numpy as np
from astropy import units as u
import matplotlib.pyplot as plt

import multiprocess as mp

import vplanet_inference as vpi

from matplotlib import rcParams
rcParams["font.family"] = "stixgeneral"
rcParams["text.usetex"] = False
rcParams["xtick.labelsize"] = 16
rcParams["ytick.labelsize"] = 16
rcParams["axes.labelsize"] = 16

# %% [markdown]
# ### XUV luminosity model from [Ribas et al. 2005](https://iopscience.iop.org/article/10.1086/427977) (R05)
#
# \begin{align}
# \frac{L_\mathrm{XUV}}{L_\mathrm{bol}} = \left\{
# 				\begin{array}{lcr}
# 					f_\mathrm{sat} &\ & t \leq t_\mathrm{sat} \\
# 					f_\mathrm{sat}\left(\frac{t}{t_\mathrm{sat}}\right)^{-\beta_\mathrm{XUV}} &\ & t > t_\mathrm{sat}
# 				\end{array}
# 				\right.,
# \end{align}
#
# where
#
# $L_\mathrm{XUV} / L_\mathrm{bol}$ is the ratio of X-ray luminosity to bolometric (total) luminosity
#
# $f_{sat}$ is the constant ratio of stellar XUV to bolometric luminosity during the saturated phase
#
# $t_{sat}$ is the duration of the saturated phase
#
# $\beta_{XUV}$ is the exponent that controls how steeply $L_{\rm XUV}$ decays after saturation

# %% [markdown]
# ### XUV luminosity model from [Johnstone et al. 2021](https://arxiv.org/abs/2009.07695) (J21)
#
# \begin{equation}
#     \frac{L_\mathrm{X}}{L_\mathrm{bol}} = \left \{
#     \begin{array}{ll}
#     C_1 Ro^{\beta_1}, & \text{if }  Ro \ge Ro_\mathrm{sat},\\
#     C_2 Ro^{\beta_2}, & \text{if }  Ro \le Ro_\mathrm{sat},\\
#     \end{array} \right.
# \end{equation}
#
# where
#
# $L_\mathrm{X} / L_\mathrm{bol}$ is the ratio of X-ray luminosity to bolometric (total) luminosity
#
# $R_o$ is the Rossby number (the rotation period / convective turnover timescale of the star)
#
# $C_1$, $C_2$, $\beta_1$, and $\beta_2$ are constants
#
# ### Best fit values from the paper:
#
# $\beta_1 = -0.135 \pm 0.030$
#
# $\beta_2 = -1.889 \pm 0.079$
#
# $Ro_\mathrm{sat} = 0.0605 \pm 0.00331$
#
# $R_\mathrm{X,sat} = 5.135 \times 10^{-4} \pm 3.320 \times 10^{-5}$
#
# $R_\mathrm{X,sat}$ is the value of $R_\mathrm{X}$ at $Ro_\mathrm{sat}$
# and the constants $C_1$, $C_2$ can be solved for using the relation:
# $R_\mathrm{X,sat} = C_1 Ro_\mathrm{sat}^{\alpha_1} = C_2 Ro_\mathrm{sat}^{\alpha_2}$
#
# Why we will use the Johnstone 2021 model:
# - model parameters are not dependent on stellar mass
# - constants have been empirically calibrated from a large sample of FGKM dwarfs (see Figure 4 of the paper)
#
# ![johnstone_fig4.png](attachment:johnstone_fig4.png)

# %%
# To run implement the Johnstone model, we will define the mean and uncertainty for the model parameters

j21 = {"beta1": (-0.135, 0.030),
       "beta2": (-1.889, 0.079),
       "Rosat": (0.0605, 0.00331),
       "RXsat": (5.135e-4, 3.320e-5)}

# %%
# Initialize the vplanet model with the input and output parameters

inpath = "../infiles/stellar/"
outpath = "output/"

inparams = {"star.dMass": u.Msun,
            "star.dRotPeriod": u.days,
            "vpl.dStopTime": u.Gyr}

outparams = {"final.star.Luminosity": u.Lsun,
             "final.star.RotPer": u.days,
             "final.star.RossbyNumber": u.dimensionless_unscaled}

vpm = vpi.VplanetModel(inparams=inparams,
                       outparams=outparams,
                       inpath=inpath,
                       outpath=outpath,
                       time_init=5e6*u.yr,
                       timesteps=1e6*u.yr,
                       verbose=True)

# %%
# Implement the additional equations needed for the Johnstone XUV luminosity model

def LXUV_model(mstar, prot, age, beta1, beta2, Rosat, RXsat):

    evol = vpm.run_model(np.array([mstar, prot, age]), remove=True)
    ross = evol["final.star.RossbyNumber"]
    lbol = evol["final.star.Luminosity"]

    C1 = RXsat / Rosat**beta1
    C2 = RXsat / Rosat**beta2
    
    rx = np.zeros(len(ross))
    for ii in range(len(ross)):
        if ross[ii] < Rosat:
            rx[ii] = C1 * ross[ii]**beta1
        else:
            rx[ii] = C2 * ross[ii]**beta2

    evol["final.star.RX"] = rx
    evol["final.star.LXUV"] = rx * lbol

    return evol

# %% [markdown]
# Test the Johnstone model for a single star with $M_* = 1\, M_{\odot}$, initial $P_{\rm rot} = 0.5$ days, $t_{\rm age} = 9$ Gyr, and constants ($\beta_1$, $\beta_2$, $Ro_\mathrm{sat}$, $R_\mathrm{X,sat}$) from the J21 paper:

# %%
# inputs: theta = [mstar, prot, age, beta1, beta2, Rosat, RXsat]

theta = np.array([0.972, 1, 10.0, j21["beta1"][0], j21["beta2"][0], j21["Rosat"][0], j21["RXsat"][0]])
evol = LXUV_model(*theta)
# Out:
# Input:
# -----------------
# star.dMass : 0.972 [solMass] (user)   --->   1.9327343943185056e+30 [kg] (vpl file)
# star.dRotPeriod : 1.0 [days] (user)   --->   86400.0 [s] (vpl file)
# vpl.dStopTime : 10.0 [Gyr] (user)   --->   3.15576e+17 [s] (vpl file)
#
# Created file output//43864846603806/vpl.in
# Created file output//43864846603806/star.in
# Executed model output//43864846603806/vpl.in 10.014 s
#
# Output:
# -----------------
# final.star.Luminosity : 1.177093260188088 [solLum]
# final.star.RossbyNumber : 3.567454 []
# final.star.RotPer : 51.62195601851852 [days]

# %%
def plot_evolution(evols , title="Johnstone 2021"):

    fig, axs = plt.subplots(3, 1, figsize=[10,14], sharex=True)

    for evol in evols:
        lbol = evol["final.star.Luminosity"].to(u.erg/u.s)
        lxuv = evol["final.star.LXUV"].to(u.erg/u.s)
        prot = evol["final.star.RotPer"]

        axs[0].plot(evol["Time"], lbol, color="k", alpha=0.5)
        axs[1].plot(evol["Time"], lxuv, color="k", alpha=0.5)
        axs[2].plot(evol["Time"], prot, color="k", alpha=0.5)
        
    axs[0].set_title(title, fontsize=24)
    axs[0].set_xscale('log')
    axs[0].set_yscale('log')

    axs[1].set_ylabel("X-ray Luminosity [{}]".format(lxuv.unit), fontsize=20)
    axs[1].set_xscale('log')
    axs[1].set_yscale('log')

    axs[2].set_ylabel("Rotation Period [{}]".format(prot.unit), fontsize=20)
    axs[2].set_xlabel("Time [yr]", fontsize=20)
    axs[2].set_xscale('log')
    axs[2].set_yscale('log')

    axs[0].set_xlim(min(evol["Time"].value), max(evol["Time"].value))
    plt.tight_layout()
    
    return fig

# %%
print(evol)
plot_evolution([evol]);
# note that the input to the plot_evolution function is a list of dictionaries, where each dictionary is the output of the LXUV_model function
# since evol is a single dictionary, we add brackets around it to make it a list
# Out:
# {'final.star.Luminosity': <VPLANETQuantity [0.60731191, 0.54434039, 0.49999791, ..., 1.17709326,
#                   1.17709326, 1.17709326] solLum>, 'final.star.RossbyNumber': <VPLANETQuantity [0.028508, 0.025507, 0.023274, ..., 3.566873, 3.567067,
#                   3.56726 ]>, 'final.star.RotPer': <VPLANETQuantity [ 1.        ,  0.89595058,  0.81654757, ..., 51.61635417,
#                   51.61915509, 51.62195602] days>, 'Time': <VPLANETQuantity [0.00000000e+00, 1.00000000e+06, 2.00000000e+06, ...,
#                   9.99800048e+09, 9.99899866e+09, 1.00000000e+10] yr>, 'final.star.RX': array([5.68403721e-04, 5.77003446e-04, 5.84184237e-04, ...,
#        2.32276347e-07, 2.32252484e-07, 2.32228748e-07]), 'final.star.LXUV': <VPLANETQuantity [3.45198351e-04, 3.14086279e-04, 2.92090898e-04, ...,
#                   2.73410922e-07, 2.73382834e-07, 2.73354894e-07] solLum>}
# /var/folders/qq/6bv7493x2078n9b_xdqntfdw0000gn/T/ipykernel_48310/2171059671.py:27: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   axs[0].set_xlim(min(evol["Time"].value), max(evol["Time"].value))

# %% [markdown]
# ### Parameter sweep
#
# Let's try sampling a range of different plausible models for Trappist-1, given the known parameters and uncertainties

# %%
# Trappist-1

nsamp = 20
mass_samp = np.random.normal(0.551, 0.068, nsamp)
prot_samp = np.random.uniform(0.01, 5.0, nsamp)
age_samp = np.ones(nsamp) * 9.0
beta1_samp = np.random.normal(j21["beta1"][0], j21["beta1"][1], nsamp)
beta2_samp = np.random.normal(j21["beta2"][0], j21["beta2"][1], nsamp)
Rosat_samp = np.random.normal(j21["Rosat"][0], j21["Rosat"][1], nsamp)
RXsat_samp = np.random.normal(j21["RXsat"][0], j21["RXsat"][1], nsamp)

thetas = np.array([mass_samp, prot_samp, age_samp, beta1_samp, beta2_samp, Rosat_samp, RXsat_samp]).T

# Run with multiple cores
ncores = mp.cpu_count()
print("number of cores available:", ncores)

with mp.Pool(ncores) as pool:
    evols = pool.starmap(LXUV_model, thetas)

# If multiple cores does not work, comment out the previous two lines and uncomment the following lines 
# evols = []
# for ii in range(nsamp):
#     evols.append(LXUV_model(*thetas[ii]))
# Out:
# number of cores available: 8
#
# Input:
# Input:
# Input:
# Input:
# Input:
# Input:
# Input:
# Input:
#
#
#
#
#
#
#
# ----------------------------------------------------------------------------------------------------------------------------------------
#
#
#
#
#
#
# star.dMass : 0.520789934879945 [solMass] (user)   --->   1.0355438470754778e+30 [kg] (vpl file)star.dMass : 0.6375447363055606 [solMass] (user)   --->   1.267700246681563e+30 [kg] (vpl file)star.dMass : 0.5540769886879532 [solMass] (user)   --->   1.1017321534337785e+30 [kg] (vpl file)star.dMass : 0.6202264528123093 [solMass] (user)   --->   1.2332644008400346e+30 [kg] (vpl file)
# star.dMass : 0.49805129509009244 [solMass] (user)   --->   9.903301112710876e+29 [kg] (vpl file)star.dMass : 0.5812979434141363 [solMass] (user)   --->   1.1558585685011458e+30 [kg] (vpl file)star.dMass : 0.6449420301840222 [solMass] (user)   --->   1.28240909884595e+30 [kg] (vpl file)
#
# star.dMass : 0.490675635493702 [solMass] (user)   --->   9.75664276926716e+29 [kg] (vpl file)
#
#
#
# star.dRotPeriod : 3.900581587303232 [days] (user)   --->   337010.24914299924 [s] (vpl file)
# star.dRotPeriod : 1.8331372017129643 [days] (user)   --->   158383.0542280001 [s] (vpl file)star.dRotPeriod : 2.410993731564389 [days] (user)   --->   208309.8584071632 [s] (vpl file)
# star.dRotPeriod : 0.34834912782428085 [days] (user)   --->   30097.364644017864 [s] (vpl file)star.dRotPeriod : 1.7037552246183163 [days] (user)   --->   147204.45140702254 [s] (vpl file)star.dRotPeriod : 3.956134033819213 [days] (user)   --->   341809.98052198 [s] (vpl file)
#
# star.dRotPeriod : 1.8652180250070247 [days] (user)   --->   161154.83736060694 [s] (vpl file)star.dRotPeriod : 2.5753288622019777 [days] (user)   --->   222508.41369425086 [s] (vpl file)
#
#
#
#
# vpl.dStopTime : 9.0 [Gyr] (user)   --->   2.840184e+17 [s] (vpl file)vpl.dStopTime : 9.0 [Gyr] (user)   --->   2.840184e+17 [s] (vpl file)
# vpl.dStopTime : 9.0 [Gyr] (user)   --->   2.840184e+17 [s] (vpl file)vpl.dStopTime : 9.0 [Gyr] (user)   --->   2.840184e+17 [s] (vpl file)vpl.dStopTime : 9.0 [Gyr] (user)   --->   2.840184e+17 [s] (vpl file)vpl.dStopTime : 9.0 [Gyr] (user)   --->   2.840184e+17 [s] (vpl file)
# vpl.dStopTime : 9.0 [Gyr] (user)   --->   2.840184e+17 [s] (vpl file)
# vpl.dStopTime : 9.0 [Gyr] (user)   --->   2.840184e+17 [s] (vpl file)
#
#
#
#
#
#
#
#
#
#
#
#
# Created file output//106690314758345/vpl.inCreated file output//10360176066781/vpl.inCreated file output//258945574820995/vpl.inCreated file output//211139619909840/vpl.inCreated file output//204610103671876/vpl.in
# Created file output//161465772994406/vpl.in
# Created file output//80116736839123/vpl.in
#
#
#
#
#
# Created file output//188240225852119/vpl.inCreated file output//211139619909840/star.inCreated file output//204610103671876/star.inCreated file output//106690314758345/star.inCreated file output//258945574820995/star.inCreated file output//10360176066781/star.in
#
# Created file output//80116736839123/star.inCreated file output//161465772994406/star.in
#
#
#
#
# Created file output//188240225852119/star.in
#
# Executed model output//188240225852119/vpl.in 10.835 s
#
# Output:
# -----------------
# final.star.Luminosity : 0.03475613897596656 [solLum]
# final.star.RossbyNumber : 1.428719 []
# final.star.RotPer : 68.65917824074074 [days]
#
# Executed model output//161465772994406/vpl.in 11.250 s
#
# Output:
# -----------------
# Executed model output//204610103671876/vpl.in 11.283 sfinal.star.Luminosity : 0.05377852664576803 [solLum]
#
#
# Output:final.star.RossbyNumber : 1.521514 []
#
#
# Input:final.star.RotPer : 66.84523148148148 [days]-----------------
#
#
# -----------------final.star.Luminosity : 0.03646794670846395 [solLum]
#
#
# star.dMass : 0.5925426282259629 [solMass] (user)   --->   1.1782176107738702e+30 [kg] (vpl file)
# final.star.RossbyNumber : 1.443194 []star.dRotPeriod : 3.2172936534599446 [days] (user)   --->   277974.1716589392 [s] (vpl file)
#
# final.star.RotPer : 68.76884259259259 [days]
# vpl.dStopTime : 9.0 [Gyr] (user)   --->   2.840184e+17 [s] (vpl file)
#
#
# Created file output//234007533094510/vpl.in
# Created file output//234007533094510/star.in
# Executed model output//106690314758345/vpl.in 11.549 sExecuted model output//258945574820995/vpl.in 11.555 s
#
#
# Output:
# Output:
#
# ----------------------------------
#
# final.star.Luminosity : 0.06551630094043887 [solLum]
# final.star.Luminosity : 0.04250974399164054 [solLum]final.star.RossbyNumber : 1.645859 []
# final.star.RossbyNumber : 1.488087 []
#
# final.star.RotPer : 68.87686342592592 [days]final.star.RotPer : 68.83675925925925 [days]
#
#
#
#
# Input:
# -----------------
# star.dMass : 0.542718697935355 [solMass] (user)   --->   1.0791472159870538e+30 [kg] (vpl file)
# star.dRotPeriod : 0.031976823217904266 [days] (user)   --->   2762.7975260269286 [s] (vpl file)
# vpl.dStopTime : 9.0 [Gyr] (user)   --->   2.840184e+17 [s] (vpl file)
#
#
# Input:
# -----------------Created file output//159217556111540/vpl.in
#
# star.dMass : 0.5243870177344347 [solMass] (user)   --->   1.042696322129064e+30 [kg] (vpl file)Created file output//159217556111540/star.in
#
# star.dRotPeriod : 0.8584799038118455 [days] (user)   --->   74172.66368934345 [s] (vpl file)
# vpl.dStopTime : 9.0 [Gyr] (user)   --->   2.840184e+17 [s] (vpl file)
#
# Created file output//62843504936038/vpl.in
# Created file output//62843504936038/star.in
# Executed model output//10360176066781/vpl.in 12.287 s
#
# Output:
# -----------------
# final.star.Luminosity : 0.08708787878787878 [solLum]
# final.star.RossbyNumber : 1.768184 []
# final.star.RotPer : 68.32712962962962 [days]
#
#
# Input:
# -----------------
# star.dMass : 0.6295345020484585 [solMass] (user)   --->   1.2517726178181373e+30 [kg] (vpl file)
# star.dRotPeriod : 4.8301030693824565 [days] (user)   --->   417320.90519464423 [s] (vpl file)
# vpl.dStopTime : 9.0 [Gyr] (user)   --->   2.840184e+17 [s] (vpl file)
#
# Created file output//23879323513936/vpl.in
# Created file output//23879323513936/star.in
#
# Input:
# -----------------
# star.dMass : 0.6404903165981655 [solMass] (user)   --->   1.2735572676103118e+30 [kg] (vpl file)
# star.dRotPeriod : 1.0246042069828876 [days] (user)   --->   88525.80348332149 [s] (vpl file)
# vpl.dStopTime : 9.0 [Gyr] (user)   --->   2.840184e+17 [s] (vpl file)
#
# Created file output//133964639168955/vpl.in
# Created file output//133964639168955/star.in
# Executed model output//211139619909840/vpl.in 12.829 s
#
# Output:
# -----------------
# final.star.Luminosity : 0.09907215256008359 [solLum]
# final.star.RossbyNumber : 1.808965 []
# final.star.RotPer : 67.1018287037037 [days]
#
#
# Input:
# -----------------
# star.dMass : 0.5994482562413903 [solMass] (user)   --->   1.1919488296831151e+30 [kg] (vpl file)
# star.dRotPeriod : 0.6186132437078851 [days] (user)   --->   53448.184256361266 [s] (vpl file)
# vpl.dStopTime : 9.0 [Gyr] (user)   --->   2.840184e+17 [s] (vpl file)
#
# Created file output//26539747731786/vpl.in
# Created file output//26539747731786/star.in
# Executed model output//80116736839123/vpl.in 13.256 s
#
# Output:
# -----------------
# final.star.Luminosity : 0.10471303552769069 [solLum]
# final.star.RossbyNumber : 1.804598 []
# final.star.RotPer : 65.72732638888888 [days]
#
#
# Input:
# -----------------
# star.dMass : 0.48954699649189165 [solMass] (user)   --->   9.734200799950615e+29 [kg] (vpl file)
# star.dRotPeriod : 0.7819802535432504 [days] (user)   --->   67563.09390613684 [s] (vpl file)
# vpl.dStopTime : 9.0 [Gyr] (user)   --->   2.840184e+17 [s] (vpl file)
#
# Created file output//89134777899888/vpl.in
# Created file output//89134777899888/star.in
#
# Input:
# -----------------
# star.dMass : 0.6099527259607057 [solMass] (user)   --->   1.2128360209594505e+30 [kg] (vpl file)
# star.dRotPeriod : 3.984796854686574 [days] (user)   --->   344286.44824492 [s] (vpl file)
# vpl.dStopTime : 9.0 [Gyr] (user)   --->   2.840184e+17 [s] (vpl file)
#
# Created file output//231048820606148/vpl.in
# Created file output//231048820606148/star.in
# Executed model output//62843504936038/vpl.in 10.463 s
#
# Output:
# -----------------
# final.star.Luminosity : 0.04358085161964472 [solLum]
# final.star.RossbyNumber : 1.471719 []
# final.star.RotPer : 67.73186342592592 [days]
#
# Executed model output//89134777899888/vpl.in 9.140 s
#
# Output:
# -----------------
# final.star.Luminosity : 0.0345037356321839 [solLum]
# final.star.RossbyNumber : 1.384134 []
# final.star.RotPer : 66.59944444444444 [days]
#
#
# Input:
# -----------------
# star.dMass : 0.6017699072646733 [solMass] (user)   --->   1.1965652234941271e+30 [kg] (vpl file)
# star.dRotPeriod : 1.6741831092240123 [days] (user)   --->   144649.42063695466 [s] (vpl file)
# vpl.dStopTime : 9.0 [Gyr] (user)   --->   2.840184e+17 [s] (vpl file)
#
# Created file output//115361375718650/vpl.in
# Created file output//115361375718650/star.in
# Executed model output//159217556111540/vpl.in 10.876 s
#
# Output:
# -----------------
# final.star.Luminosity : 0.049578552769070014 [solLum]
# final.star.RossbyNumber : 1.409168 []
# final.star.RotPer : 63.07349537037037 [days]
#
# Executed model output//133964639168955/vpl.in 10.231 s
#
# Output:
# -----------------
# final.star.Luminosity : 0.10127944096133752 [solLum]
# final.star.RossbyNumber : 1.776833 []
# final.star.RotPer : 65.43516203703703 [days]
#
#
# Input:
# -----------------
# star.dMass : 0.5852456089718642 [solMass] (user)   --->   1.1637081456623466e+30 [kg] (vpl file)
# star.dRotPeriod : 4.314901156280506 [days] (user)   --->   372807.4599026357 [s] (vpl file)
# vpl.dStopTime : 9.0 [Gyr] (user)   --->   2.840184e+17 [s] (vpl file)Executed model output//234007533094510/vpl.in 11.660 s
#
#
# Created file output//149419665294537/vpl.in
# Output:
#
# Created file output//149419665294537/star.in-----------------
#
# final.star.Luminosity : 0.07110937826541275 [solLum]
# final.star.RossbyNumber : 1.694568 []
# final.star.RotPer : 69.40041666666666 [days]
#
#
# Input:
# -----------------
# star.dMass : 0.5215521069207854 [solMass] (user)   --->   1.0370593574846549e+30 [kg] (vpl file)
# star.dRotPeriod : 4.688412991748717 [days] (user)   --->   405078.8824870892 [s] (vpl file)
# vpl.dStopTime : 9.0 [Gyr] (user)   --->   2.840184e+17 [s] (vpl file)
#
# Created file output//101315618862323/vpl.in
# Created file output//101315618862323/star.in
# Executed model output//23879323513936/vpl.in 10.964 s
#
# Output:
# -----------------
# final.star.Luminosity : 0.09332251828631138 [solLum]
# final.star.RossbyNumber : 1.796133 []
# final.star.RotPer : 67.92304398148148 [days]
#
#
# Input:
# -----------------
# star.dMass : 0.5906757960224854 [solMass] (user)   --->   1.1745055831935387e+30 [kg] (vpl file)
# star.dRotPeriod : 3.8943998477708393 [days] (user)   --->   336476.1468474005 [s] (vpl file)
# vpl.dStopTime : 9.0 [Gyr] (user)   --->   2.840184e+17 [s] (vpl file)
#
# Created file output//243301874403469/vpl.in
# Created file output//243301874403469/star.in
# Executed model output//26539747731786/vpl.in 11.267 s
#
# Output:
# -----------------
# final.star.Luminosity : 0.07477283176593522 [solLum]
# final.star.RossbyNumber : 1.662433 []
# final.star.RotPer : 67.16045138888889 [days]
#
# Executed model output//231048820606148/vpl.in 10.691 s
#
# Output:
# -----------------
# final.star.Luminosity : 0.08073427377220481 [solLum]
# final.star.RossbyNumber : 1.744328 []
# final.star.RotPer : 68.95230324074073 [days]
#
# Executed model output//101315618862323/vpl.in 6.462 s
#
# Output:
# -----------------
# final.star.Luminosity : 0.042733934169278995 [solLum]
# final.star.RossbyNumber : 1.521256 []
# final.star.RotPer : 70.29543981481481 [days]
#
# Executed model output//115361375718650/vpl.in 6.976 s
#
# Output:
# -----------------
# final.star.Luminosity : 0.0760448014629049 [solLum]
# final.star.RossbyNumber : 1.698365 []
# final.star.RotPer : 68.29253472222221 [days]
#
# Executed model output//243301874403469/vpl.in 6.250 s
#
# Output:
# -----------------
# final.star.Luminosity : 0.07014835423197492 [solLum]
# final.star.RossbyNumber : 1.695577 []
# final.star.RotPer : 69.69547453703703 [days]
#
# Executed model output//149419665294537/vpl.in 6.836 s
#
# Output:
# -----------------
# final.star.Luminosity : 0.0674273249738767 [solLum]
# final.star.RossbyNumber : 1.684603 []
# final.star.RotPer : 69.97284722222221 [days]

# %% [markdown]
# Next, let's plot the models we just ran and see how the evolution models (black lines) compare to the observational data (red lines) of the system at present day
# using data from [https://jbirky.github.io/yupra/docs/datasets.html](https://jbirky.github.io/yupra/docs/datasets.html)
#
# Note: make sure that the units are consistent with those in the data table.
#
# Then plot the observational constraints and uncertainties on top of the models, to compare how well the models match the data.

# %%
# data = [mean, lower error, upper error]

Lbol_data = np.array([0.056, -0.068, 0.068]) * u.Lsun
Lbol_data = Lbol_data.to(u.erg/u.s).value

Lxuv_data = np.array([2.73e+27, -8.97e+26, 8.97e+26])  * u.Lsun
Lxuv_data = Lxuv_data.value

Prot_data = np.array([19.34, 0, 0]) * u.day
Prot_data = Prot_data.value

age_data = np.array([0, 0, 0]) * u.Gyr
age_data = age_data.to(u.yr).value

# %%
def plot_evolutions(evols , title="Kepler-138 model samples"):
    fig = plot_evolution(evols, title="Kepler-138 model samples")
    axs = fig.axes

    axs[0].axhline(Lbol_data[0], color="r", linestyle="--")
    axs[0].axhspan(Lbol_data[0]+Lbol_data[1], Lbol_data[0]+Lbol_data[2], color="r", alpha=0.2)

    axs[1].axhline(Lxuv_data[0], color="r", linestyle="--")
    axs[1].axhspan(Lxuv_data[0]+Lxuv_data[1], Lxuv_data[0]+Lxuv_data[2], color="r", alpha=0.2)

    axs[2].axhline(Prot_data[0], color="r", linestyle="--")
    axs[2].axhspan(Prot_data[0]+Prot_data[1], Prot_data[0]+Prot_data[2], color="r", alpha=0.2)

    for ii in range(len(axs)):
        axs[ii].axvline(age_data[0], color="r", linestyle="--")
        axs[ii].axvspan(age_data[0]+age_data[1], age_data[0]+age_data[2], color="r", alpha=0.2)

    fig.show()

# %% [markdown]
# Note: for the Trappist system, the constraints on rotation period and xray luminosity suggest a younger age (~1-3 Gyr, based on where the models intersect the horizontal red lines) than what is reported in literature ($7.6\pm2.2$ Gyr, from Burgasser and Mamajek 2017). However, age is one of the most difficult parameters to reliably measure for a star, so it is not too surprising that the literature age is inconsistent.

# %%
plot_evolutions(evols)
# Out:
# /var/folders/qq/6bv7493x2078n9b_xdqntfdw0000gn/T/ipykernel_48310/2171059671.py:27: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   axs[0].set_xlim(min(evol["Time"].value), max(evol["Time"].value))
# /var/folders/qq/6bv7493x2078n9b_xdqntfdw0000gn/T/ipykernel_48310/192438175.py:18: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
### Kepler-138
