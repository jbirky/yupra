# %%
import numpy as np
from astropy import units as u
import matplotlib.pyplot as plt
import multiprocessing as mp

import vplanet_inference as vpi

# %%
from matplotlib import rcParams
rcParams['font.family'] = 'stixgeneral'
rcParams['text.usetex'] = False
rcParams['xtick.labelsize'] = 16
rcParams['ytick.labelsize'] = 16
rcParams['axes.labelsize'] = 16

# %% [markdown]
# ### XUV luminosity model from [Ribas et al. 2005](https://iopscience.iop.org/article/10.1086/427977) (R05)
#
# \begin{align}
# \frac{L_\mathrm{XUV}}{L_\mathrm{bol}} = \left\{
# 				\begin{array}{lcr}
# 					f_\mathrm{sat} &\ & t \leq t_\mathrm{sat} \\
# 					f_\mathrm{sat}\left(\frac{t}{t_\mathrm{sat}}\right)^{-\beta_\mathrm{XUV}} &\ & t > t_\mathrm{sat}
# 				\end{array}
# 				\right.,
# \end{align}
#
# where
#
# $L_\mathrm{XUV} / L_\mathrm{bol}$ is the ratio of X-ray luminosity to bolometric (total) luminosity
#
# $f_{sat}$ is the constant ratio of stellar XUV to bolometric luminosity during the saturated phase
#
# $t_{sat}$ is the duration of the saturated phase
#
# $\beta_{XUV}$ is the exponent that controls how steeply $L_{\rm XUV}$ decays after saturation

# %% [markdown]
# ### XUV luminosity model from [Johnstone et al. 2021](https://arxiv.org/abs/2009.07695) (J21)
#
# \begin{equation}
#     \frac{L_\mathrm{X}}{L_\mathrm{bol}} = \left \{
#     \begin{array}{ll}
#     C_1 Ro^{\beta_1}, & \text{if }  Ro \ge Ro_\mathrm{sat},\\
#     C_2 Ro^{\beta_2}, & \text{if }  Ro \le Ro_\mathrm{sat},\\
#     \end{array} \right.
# \end{equation}
#
# where
#
# $L_\mathrm{X} / L_\mathrm{bol}$ is the ratio of X-ray luminosity to bolometric (total) luminosity
#
# $R_o$ is the Rossby number (the rotation period / convective turnover timescale of the star)
#
# $C_1$, $C_2$, $\beta_1$, and $\beta_2$ are constants
#
# ### Best fit values from the paper:
#
# $\beta_1 = -0.135 \pm 0.030$
#
# $\beta_2 = -1.889 \pm 0.079$
#
# $Ro_\mathrm{sat} = 0.0605 \pm 0.00331$
#
# $R_\mathrm{X,sat} = 5.135 \times 10^{-4} \pm 3.320 \times 10^{-5}$
#
# $R_\mathrm{X,sat}$ is the value of $R_\mathrm{X}$ at $Ro_\mathrm{sat}$
# and the constants $C_1$, $C_2$ can be solved for using the relation:
# $R_\mathrm{X,sat} = C_1 Ro_\mathrm{sat}^{\alpha_1} = C_2 Ro_\mathrm{sat}^{\alpha_2}$
#
# Why we will use the Johnstone 2021 model:
# - model parameters are not dependent on stellar mass
# - constants have been empirically calibrated from a large sample of FGKM dwarfs (see Figure 4 of the paper)
#
# ![johnstone_fig4.png](attachment:johnstone_fig4.png)

# %%
# To run implement the Johnstone model, we will define the mean and uncertainty for the model parameters

j21 = {"beta1": (-0.135, 0.030),
       "beta2": (-1.889, 0.079),
       "Rosat": (0.0605, 0.00331),
       "RXsat": (5.135e-4, 3.320e-5)}

# %%
# Initialize the vplanet model with the input and output parameters

inpath = "../infiles/stellar/"
outpath = "output/"

inparams = {"star.dMass": u.Msun,
            "star.dRotPeriod": u.days,
            "vpl.dStopTime": u.Gyr}

outparams = {"final.star.Luminosity": u.Lsun,
             "final.star.RotPer": u.days,
             "final.star.RossbyNumber": u.dimensionless_unscaled,
             "final.star.Radius": u.Rsun}

vpm = vpi.VplanetModel(inparams=inparams,
                       outparams=outparams,
                       inpath=inpath,
                       outpath=outpath,
                       time_init=5e6*u.yr,
                       timesteps=1e6*u.yr,
                       verbose=True)

# %%
# Implement the additional equations needed for the Johnstone XUV luminosity model
def FluxToLuminosity(Flux,Radius):
    Luminosity=Flux*4*np.pi*Radius**2
    return Luminosity
def LuminosityToFlux(Luminosity,Radius):
    Flux =  Luminosity/(Radius**2*4*np.pi)
    return Flux
def EUV_relation(LuminosityXray,Radius):
    FluxXray = LuminosityToFlux(LuminosityXray.cgs.value,Radius.cgs.value)
    LogFluxEUV1 = 2.04 + 0.681*np.log10(FluxXray)
    FluxEUV1=10**LogFluxEUV1
    LogFluxEUV2= -0.341 + 0.920*LogFluxEUV1
    FluxEUV2=10**LogFluxEUV2
    FluxEUV=(FluxEUV1+FluxEUV2)* u.erg / u.s / u.cm**2
    LuminosityEUV=FluxToLuminosity(FluxEUV,Radius)
    return LuminosityEUV
def LXUV_model(mstar, prot, age, beta1, beta2, Rosat, RXsat):

    evol = vpm.run_model(np.array([mstar, prot, age]), remove=True)
    ross = evol["final.star.RossbyNumber"]
    lbol = evol["final.star.Luminosity"]
    Radius = evol["final.star.Radius"]

    C1 = RXsat / Rosat**beta1
    C2 = RXsat / Rosat**beta2
    
    rx = np.zeros(len(ross))
    for ii in range(len(ross)):
        if ross[ii] < Rosat:
            rx[ii] = C1 * ross[ii]**beta1
        else:
            rx[ii] = C2 * ross[ii]**beta2

    evol["final.star.RX"] = rx
    evol["final.star.LXray"] = rx * lbol
    evol["final.star.LEUV"]= EUV_relation(evol["final.star.LXray"],Radius)
    evol["final.star.LXUV"]= evol["final.star.LXray"]+evol["final.star.LEUV"]
    return evol

# %% [markdown]
# Test the Johnstone model for a single star with $M_* = 1\, M_{\odot}$, initial $P_{\rm rot} = 0.5$ days, $t_{\rm age} = 9$ Gyr, and constants ($\beta_1$, $\beta_2$, $Ro_\mathrm{sat}$, $R_\mathrm{X,sat}$) from the J21 paper:

# %%
# inputs: theta = [mstar, prot, age, beta1, beta2, Rosat, RXsat]

theta = np.array([0.696, 42.3, 12.46, j21["beta1"][0], j21["beta2"][0], j21["Rosat"][0], j21["RXsat"][0]])
evol = LXUV_model(*theta)
# Out:
# Input:
# -----------------
# star.dMass : 0.696 [solMass] (user)   --->   1.3839332700058434e+30 [kg] (vpl file)
# star.dRotPeriod : 42.3 [days] (user)   --->   3654719.9999999995 [s] (vpl file)
# vpl.dStopTime : 12.46 [Gyr] (user)   --->   3.93207696e+17 [s] (vpl file)
#
# Created file output//235585855697245/vpl.in
# Created file output//235585855697245/star.in
# Executed model output//235585855697245/vpl.in 9.036 s
#
# Output:
# -----------------
# final.star.Luminosity : 0.15573116509926854 [solLum]
# final.star.Radius : 0.6575069713957165 [solRad]
# final.star.RossbyNumber : 2.374735 []
# final.star.RotPer : 75.42469907407407 [days]

# %%
def plot_evolution(evols, title="HD 219134"):

    fig, axs = plt.subplots(3, 1, figsize=[10,14], sharex=True)

    for evol in evols:
        lbol = evol["final.star.Luminosity"].to(u.erg/u.s)
        lxuv = evol["final.star.LXUV"].to(u.erg/u.s)
        prot = evol["final.star.RotPer"]

        axs[0].plot(evol["Time"], lbol, color="k", alpha=0.5)
        axs[1].plot(evol["Time"], lxuv, color="k", alpha=0.5)
        axs[2].plot(evol["Time"], prot, color="k", alpha=0.5)

    axs[0].set_title(title, fontsize=24)
    axs[0].set_ylabel("Bolometric Luminosity [{}]".format(lbol.unit), fontsize=20)
    axs[0].set_xscale('log')
    axs[0].set_yscale('log')

    axs[1].set_ylabel("XUV Luminosity [{}]".format(lxuv.unit), fontsize=20)
    axs[1].set_xscale('log')
    axs[1].set_yscale('log')

    axs[2].set_ylabel("Rotation Period [{}]".format(prot.unit), fontsize=20)
    axs[2].set_xlabel("Time [yr]", fontsize=20)
    axs[2].set_xscale('log')
    axs[2].set_yscale('log')

    axs[0].set_xlim(min(evol["Time"].value), max(evol["Time"].value))
    plt.tight_layout()
    
    return fig

# %%
plot_evolution([evol]);

# note that the input to the plot_evolution function is a list of dictionaries, where each dictionary is the output of the LXUV_model function
# since evol is a single dictionary, we add brackets around it to make it a list
# Out:
# /tmp/ipykernel_87498/2212907181.py:28: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   axs[0].set_xlim(min(evol["Time"].value), max(evol["Time"].value))

# %% [markdown]
# ### Parameter sweep
#
# Let's try sampling a range of different plausible models for Trappist-1, given the known parameters and uncertainties

# %%
# Trappist-1
#standarddeviation(+/- 0.01)
#
nsamp = 20
mass_samp = np.random.normal(0.696, 0.078, nsamp)
prot_samp = np.random.uniform(42.3, 0.1, nsamp)
age_samp = np.ones(nsamp) * 11.0
beta1_samp = np.random.normal(j21["beta1"][0], j21["beta1"][1], nsamp)
beta2_samp = np.random.normal(j21["beta2"][0], j21["beta2"][1], nsamp)
Rosat_samp = np.random.normal(j21["Rosat"][0], j21["Rosat"][1], nsamp)
RXsat_samp = np.random.normal(j21["RXsat"][0], j21["RXsat"][1], nsamp)

thetas = np.array([mass_samp, prot_samp, age_samp, beta1_samp, beta2_samp, Rosat_samp, RXsat_samp]).T

# Run with multiple cores
ncores = mp.cpu_count()
print("number of cores available:", ncores)
with mp.Pool(ncores) as pool:
    evols = pool.starmap(LXUV_model, thetas)

# If multiple cores does not work, comment out the previous two lines and uncomment the following lines 
# evols = []
# for ii in range(nsamp):
#     evols.append(LXUV_model(*thetas[ii]))
# Out:
# number of cores available: 12
#
# Input:
# Input:
# Input:
# Input:
# Input:
# Input:
#
# -----------------
# Input:
#
# Input:
# Input:
# Input:
#
#
# Input:star.dMass : 0.6624324776922903 [solMass] (user)   --->   1.3171872773143165e+30 [kg] (vpl file)
# -----------------
#
# -----------------
#
# Input:
# -----------------
#
# -----------------star.dMass : 0.6835113140586037 [solMass] (user)   --->   1.359100643607923e+30 [kg] (vpl file)
# -----------------
#
# -----------------star.dMass : 0.6568593408436346 [solMass] (user)   --->   1.3061055969936985e+30 [kg] (vpl file)
# -----------------
# star.dRotPeriod : 18.939950697602832 [days] (user)   --->   1636411.7402728847 [s] (vpl file)
# -----------------
# ----------------------------------
#
# star.dMass : 0.6749289869574367 [solMass] (user)   --->   1.3420354596864032e+30 [kg] (vpl file)
#
# star.dMass : 0.7134080113659578 [solMass] (user)   --->   1.4185475316351377e+30 [kg] (vpl file)
#
# star.dRotPeriod : 7.387054040146921 [days] (user)   --->   638241.469068694 [s] (vpl file)
# star.dMass : 0.7166106478542843 [solMass] (user)   --->   1.424915685640784e+30 [kg] (vpl file)
# star.dRotPeriod : 29.012616831330853 [days] (user)   --->   2506690.0942269857 [s] (vpl file)
# vpl.dStopTime : 11.0 [Gyr] (user)   --->   3.471336e+17 [s] (vpl file)
#
# star.dMass : 0.8817702196653026 [solMass] (user)   --->   1.7533206084700762e+30 [kg] (vpl file)star.dMass : 0.5850062247857465 [solMass] (user)   --->   1.163232151783781e+30 [kg] (vpl file)star.dRotPeriod : 33.32730022902127 [days] (user)   --->   2879478.7397874375 [s] (vpl file)star.dRotPeriod : 32.63913087036212 [days] (user)   --->   2820020.9071992873 [s] (vpl file)
#
#
#
# star.dMass : 0.7510637907208114 [solMass] (user)   --->   1.4934226549931567e+30 [kg] (vpl file)vpl.dStopTime : 11.0 [Gyr] (user)   --->   3.471336e+17 [s] (vpl file)vpl.dStopTime : 11.0 [Gyr] (user)   --->   3.471336e+17 [s] (vpl file)star.dRotPeriod : 41.42628529656651 [days] (user)   --->   3579231.0496233464 [s] (vpl file)star.dRotPeriod : 29.167932692266014 [days] (user)   --->   2520109.3846117835 [s] (vpl file)vpl.dStopTime : 11.0 [Gyr] (user)   --->   3.471336e+17 [s] (vpl file)-----------------star.dMass : 0.6768842361231875 [solMass] (user)   --->   1.3459232964272563e+30 [kg] (vpl file)
#
#
# star.dRotPeriod : 9.468713012879817 [days] (user)   --->   818096.8043128162 [s] (vpl file)vpl.dStopTime : 11.0 [Gyr] (user)   --->   3.471336e+17 [s] (vpl file)
#
#
#
#
# vpl.dStopTime : 11.0 [Gyr] (user)   --->   3.471336e+17 [s] (vpl file)
#
#
#
# vpl.dStopTime : 11.0 [Gyr] (user)   --->   3.471336e+17 [s] (vpl file)star.dRotPeriod : 13.923420335865622 [days] (user)   --->   1202983.5170187897 [s] (vpl file)vpl.dStopTime : 11.0 [Gyr] (user)   --->   3.471336e+17 [s] (vpl file)star.dRotPeriod : 31.453619183437766 [days] (user)   --->   2717592.697449023 [s] (vpl file)
#
#
#
#
#
#
#
#
# vpl.dStopTime : 11.0 [Gyr] (user)   --->   3.471336e+17 [s] (vpl file)
#
# star.dMass : 0.6969387832499155 [solMass] (user)   --->   1.3857999558864217e+30 [kg] (vpl file)Created file output//259620140532802/vpl.in
# star.dMass : 0.7769415511847857 [solMass] (user)   --->   1.5448782493312827e+30 [kg] (vpl file)
#
#
# star.dRotPeriod : 11.820797540355272 [days] (user)   --->   1021316.9074866956 [s] (vpl file)Created file output//259620140532802/star.in
# star.dRotPeriod : 10.073855665052136 [days] (user)   --->   870381.1294605045 [s] (vpl file)
#
#
#
#
# vpl.dStopTime : 11.0 [Gyr] (user)   --->   3.471336e+17 [s] (vpl file)Created file output//179223155408652/vpl.invpl.dStopTime : 11.0 [Gyr] (user)   --->   3.471336e+17 [s] (vpl file)Created file output//220124349253966/vpl.in
# vpl.dStopTime : 11.0 [Gyr] (user)   --->   3.471336e+17 [s] (vpl file)
#
#
#
#
#
#
# Created file output//232701356078647/vpl.inCreated file output//275174713469097/vpl.in
# Created file output//156130244148306/vpl.inCreated file output//220124349253966/star.in
# Created file output//275174713469097/star.in
#
# Created file output//179223155408652/star.in
# Created file output//206167133147862/vpl.in
# Created file output//66986513783904/vpl.inCreated file output//232701356078647/star.inCreated file output//19944872212888/vpl.in
#
# Created file output//99974855382795/vpl.in
# Created file output//156130244148306/star.inCreated file output//163697842871486/vpl.in
# Created file output//206167133147862/star.inCreated file output//96403679791374/vpl.in
#
#
#
# Created file output//66986513783904/star.inCreated file output//19944872212888/star.inCreated file output//99974855382795/star.in
#
# Created file output//163697842871486/star.in
#
#
# Created file output//96403679791374/star.in
#
# Executed model output//156130244148306/vpl.in 15.238 s
#
# Output:
# -----------------
# final.star.Luminosity : 0.1160649947753396 [solLum]
# final.star.Radius : 0.6214204398447606 [solRad]
# final.star.RossbyNumber : 2.124388 []
# final.star.RotPer : 74.57412037037037 [days]
#
# Executed model output//66986513783904/vpl.in 15.889 s
#
# Output:
# -----------------
# final.star.Luminosity : 0.06803939393939394 [solLum]
# final.star.Radius : 0.5543040103492884 [solRad]
# final.star.RossbyNumber : 1.915408 []
# final.star.RotPer : 79.09695601851851 [days]
#
# Executed model output//259620140532802/vpl.in 16.329 s
#
# Output:
# -----------------
# final.star.Luminosity : 0.12102648902821316 [solLum]
# final.star.Radius : 0.6265587178381485 [solRad]
# final.star.RossbyNumber : 2.12483 []
# final.star.RotPer : 73.55811342592592 [days]
#
#
# Input:
# -----------------
# star.dMass : 0.6629720738956973 [solMass] (user)   --->   1.3182602157313623e+30 [kg] (vpl file)
# star.dRotPeriod : 5.403211114410318 [days] (user)   --->   466837.4402850515 [s] (vpl file)
# vpl.dStopTime : 11.0 [Gyr] (user)   --->   3.471336e+17 [s] (vpl file)
#
# Created file output//210627304913470/vpl.in
# Created file output//210627304913470/star.in
#
# Input:
# -----------------
# star.dMass : 0.7261811487417448 [solMass] (user)   --->   1.443945764072935e+30 [kg] (vpl file)
# star.dRotPeriod : 31.468665559403952 [days] (user)   --->   2718892.7043325016 [s] (vpl file)
# vpl.dStopTime : 11.0 [Gyr] (user)   --->   3.471336e+17 [s] (vpl file)
#
# Created file output//266842594145339/vpl.in
# Created file output//266842594145339/star.in
#
# Input:
# -----------------
# star.dMass : 0.7361400749645917 [solMass] (user)   --->   1.463748191275997e+30 [kg] (vpl file)
# star.dRotPeriod : 39.76213872464913 [days] (user)   --->   3435448.7858096845 [s] (vpl file)
# vpl.dStopTime : 11.0 [Gyr] (user)   --->   3.471336e+17 [s] (vpl file)
#
# Created file output//60050171661238/vpl.in
# Created file output//60050171661238/star.in
# Executed model output//99974855382795/vpl.in 17.730 s
#
# Output:
# -----------------
# final.star.Luminosity : 0.15683312434691746 [solLum]
# final.star.Radius : 0.658372574385511 [solRad]
# final.star.RossbyNumber : 2.207965 []
# final.star.RotPer : 69.95496527777777 [days]
#
# Executed model output//19944872212888/vpl.in 17.840 s
#
# Output:
# -----------------
# final.star.Luminosity : 0.13293620689655172 [solLum]
# final.star.Radius : 0.6380802069857697 [solRad]
# final.star.RossbyNumber : 2.133361 []
# final.star.RotPer : 71.55608796296296 [days]
#
# Executed model output//206167133147862/vpl.in 18.374 s
#
# Output:
# -----------------
# final.star.Luminosity : 0.14178759143155695 [solLum]
# final.star.Radius : 0.6459928129941066 [solRad]
# final.star.RossbyNumber : 2.189683 []
# final.star.RotPer : 71.84590277777778 [days]
#
#
# Input:
# -----------------
# star.dMass : 0.6810994150272308 [solMass] (user)   --->   1.354304799766814e+30 [kg] (vpl file)
# star.dRotPeriod : 37.51664445048024 [days] (user)   --->   3241438.0805214928 [s] (vpl file)
# vpl.dStopTime : 11.0 [Gyr] (user)   --->   3.471336e+17 [s] (vpl file)
#
# Created file output//118645966270822/vpl.in
# Created file output//118645966270822/star.in
#
# Input:
# -----------------
# star.dMass : 0.650487948619453 [solMass] (user)   --->   1.293436657805047e+30 [kg] (vpl file)
# star.dRotPeriod : 27.06483572983886 [days] (user)   --->   2338401.807058078 [s] (vpl file)
# vpl.dStopTime : 11.0 [Gyr] (user)   --->   3.471336e+17 [s] (vpl file)
#
# Created file output//165506091573457/vpl.in
# Created file output//165506091573457/star.in
#
# Input:
# -----------------
# star.dMass : 0.6681276258205564 [solMass] (user)   --->   1.3285115660676484e+30 [kg] (vpl file)
# star.dRotPeriod : 26.651668159517286 [days] (user)   --->   2302704.1289822934 [s] (vpl file)
# vpl.dStopTime : 11.0 [Gyr] (user)   --->   3.471336e+17 [s] (vpl file)
#
# Created file output//20943592878972/vpl.in
# Created file output//20943592878972/star.in
# Executed model output//220124349253966/vpl.in 19.478 s
#
# Output:
# -----------------
# final.star.Luminosity : 0.17734934691745038 [solLum]
# final.star.Radius : 0.6763947103636625 [solRad]
# final.star.RossbyNumber : 2.281822 []
# final.star.RotPer : 69.31791666666666 [days]
#
# Executed model output//179223155408652/vpl.in 19.595 s
#
# Output:
# -----------------
# final.star.Luminosity : 0.23481948798328106 [solLum]
# final.star.Radius : 0.7190838004887163 [solRad]
# Executed model output//163697842871486/vpl.in 19.566 s
# final.star.RossbyNumber : 2.371422 []
#
# Output:final.star.RotPer : 65.22037037037036 [days]
#
#
# -----------------
# final.star.Luminosity : 0.1349028474399164 [solLum]
# final.star.Radius : 0.6398828518039384 [solRad]
# final.star.RossbyNumber : 2.173567 []
# final.star.RotPer : 72.5415625 [days]
#
#
# Input:
# -----------------
# star.dMass : 0.7369811899425104 [solMass] (user)   --->   1.465420672600483e+30 [kg] (vpl file)
# star.dRotPeriod : 10.77179795714931 [days] (user)   --->   930683.3434977004 [s] (vpl file)
# vpl.dStopTime : 11.0 [Gyr] (user)   --->   3.471336e+17 [s] (vpl file)
#
# Created file output//214603197058772/vpl.in
# Created file output//214603197058772/star.in
#
# Input:
# -----------------
# star.dMass : 0.6233967274123242 [solMass] (user)   --->   1.2395682061475277e+30 [kg] (vpl file)
# star.dRotPeriod : 5.378083843593565 [days] (user)   --->   464666.444086484 [s] (vpl file)
# vpl.dStopTime : 11.0 [Gyr] (user)   --->   3.471336e+17 [s] (vpl file)
#
# Created file output//153865443346281/vpl.in
# Created file output//153865443346281/star.in
# Executed model output//232701356078647/vpl.in 20.592 s
#
# Output:
# -----------------
# final.star.Luminosity : 0.18163419540229886 [solLum]
# final.star.Radius : 0.6800254420008623 [solRad]
# final.star.RossbyNumber : 2.296125 []
# final.star.RotPer : 69.18155092592592 [days]
#
# Executed model output//96403679791374/vpl.in 21.991 s
#
# Output:
# -----------------
# final.star.Luminosity : 0.28477978056426334 [solLum]
# final.star.Radius : 0.7484205835848785 [solRad]
# final.star.RossbyNumber : 2.470485 []
# final.star.RotPer : 63.184247685185184 [days]
#
# Executed model output//275174713469097/vpl.in 27.093 s
#
# Output:
# -----------------
# final.star.Luminosity : 0.6492437304075235 [solLum]
# final.star.Radius : 0.924709357481673 [solRad]
# final.star.RossbyNumber : 3.130662 []
# final.star.RotPer : 57.84715277777777 [days]
#
# Executed model output//210627304913470/vpl.in 18.815 s
#
# Output:
# -----------------
# final.star.Luminosity : 0.12151799895506792 [solLum]
# final.star.Radius : 0.627056202386086 [solRad]
# final.star.RossbyNumber : 2.094682 []
# final.star.RotPer : 72.41633101851852 [days]
#
# Executed model output//266842594145339/vpl.in 18.549 s
#
# Output:
# -----------------
# final.star.Luminosity : 0.1950655433646813 [solLum]
# final.star.Radius : 0.6908750898375736 [solRad]
# final.star.RossbyNumber : 2.319466 []
# final.star.RotPer : 68.17253472222222 [days]
#
# Executed model output//60050171661238/vpl.in 18.686 s
#
# Output:
# -----------------
# final.star.Luminosity : 0.21009757053291536 [solLum]
# final.star.Radius : 0.7021653011355469 [solRad]
# final.star.RossbyNumber : 2.354364 []Executed model output//118645966270822/vpl.in 17.488 s
#
#
# Output:
# final.star.RotPer : 67.40663194444444 [days]-----------------
#
#
# final.star.Luminosity : 0.1392421630094044 [solLum]
# final.star.Radius : 0.6437691533707057 [solRad]
# final.star.RossbyNumber : 2.187937 []
# final.star.RotPer : 72.23609953703703 [days]
#
# Executed model output//165506091573457/vpl.in 17.353 s
#
# Output:
# -----------------
# final.star.Luminosity : 0.11064153605015674 [solLum]
# final.star.Radius : 0.6155462124478942 [solRad]
# final.star.RossbyNumber : 2.10402 []
# final.star.RotPer : 75.03518518518518 [days]
#
# Executed model output//153865443346281/vpl.in 15.875 s
#
# Output:
# -----------------
# final.star.Luminosity : 0.09027102925809821 [solLum]
# final.star.Radius : 0.5905689233865171 [solRad]
# final.star.RossbyNumber : 1.994109 []
# final.star.RotPer : 75.9502662037037 [days]
#
# Executed model output//20943592878972/vpl.in 18.101 s
#
# Output:
# -----------------
# final.star.Luminosity : 0.12631580459770114 [solLum]
# final.star.Radius : 0.6318095443438263 [solRad]
# final.star.RossbyNumber : 2.147197 []
# final.star.RotPer : 73.27437499999999 [days]
#
# Executed model output//214603197058772/vpl.in 17.588 s
#
# Output:
# -----------------
# final.star.Luminosity : 0.21141899164054334 [solLum]
# final.star.Radius : 0.703118729337358 [solRad]
# final.star.RossbyNumber : 2.328705 []
# final.star.RotPer : 66.52306712962962 [days]

# %%
def EUV_relation(Lxray, radius):

    Fxray = LuminosityToFlux(Lxray.cgs.value, radius.cgs.value)
    log_FEUV1 = 2.04 + 0.681 * np.log10(Fxray)
    FEUV1 = 10**log_FEUV1
    log_FEUV2 = -0.341 + 0.920 * log_FEUV1
    FEUV2 = 10**log_FEUV2
    FEUV = (FEUV1 + FEUV2) * u.erg / u.s / u.cm**2

    return FluxToLuminosity(FEUV, radius)

# %% [markdown]
# Next, let's plot the models we just ran and see how the evolution models (black lines) compare to the observational data (red lines) of the system at present day
# using data from [https://jbirky.github.io/yupra/docs/datasets.html](https://jbirky.github.io/yupra/docs/datasets.html)
#
# Note: make sure that the units are consistent with those in the data table.
#
# Then plot the observational constraints and uncertainties on top of the models, to compare how well the models match the data.

# %%
# data = [mean, lower error, upper error]
#HD 219134
Lbol_data = np.array([0.264, -0.004, 0.004]) * u.Lsun
Lbol_data = Lbol_data.to(u.erg/u.s).value

Lxuv_data = np.array([9.7e+26, -1.57e+26, 1.57e+26]) * u.erg/u.s
Lxuv_data = Lxuv_data.value

Prot_data = np.array([42.3, -0.1, 0.1]) * u.day
Prot_data = Prot_data.value

age_data = np.array([11, -2.2, 2.2]) * u.Gyr
age_data = age_data.to(u.yr).value

# %%
fig = plot_evolution(evols, title="HD 219134")
axs = fig.axes

axs[0].axhline(Lbol_data[0], color="r", linestyle="--")
axs[0].axhspan(Lbol_data[0]+Lbol_data[1], Lbol_data[0]+Lbol_data[2], color="r", alpha=0.2)

axs[1].axhline(Lxuv_data[0], color="r", linestyle="--")
axs[1].axhspan(Lxuv_data[0]+Lxuv_data[1], Lxuv_data[0]+Lxuv_data[2], color="r", alpha=0.2)

axs[2].axhline(Prot_data[0], color="r", linestyle="--")
axs[2].axhspan(Prot_data[0]+Prot_data[1], Prot_data[0]+Prot_data[2], color="r", alpha=0.2)

for ii in range(len(axs)):
    axs[ii].axvline(age_data[0], color="r", linestyle="--")
    axs[ii].axvspan(age_data[0]+age_data[1], age_data[0]+age_data[2], color="r", alpha=0.2)

fig.show()
# Out:
# /tmp/ipykernel_87498/2212907181.py:28: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   axs[0].set_xlim(min(evol["Time"].value), max(evol["Time"].value))
# /tmp/ipykernel_87498/2027009760.py:17: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# Note: for the Trappist system, the constraints on rotation period and xray luminosity suggest a younger age (~1-3 Gyr, based on where the models intersect the horizontal red lines) than what is reported in literature ($7.6\pm2.2$ Gyr, from Burgasser and Mamajek 2017). However, age is one of the most difficult parameters to reliably measure for a star, so it is not too surprising that the literature age is inconsistent.
