# %%
import numpy as np
from astropy import units as u
import matplotlib.pyplot as plt
import multiprocessing as mp

import vplanet_inference as vpi

# %% [markdown]
# ### XUV luminosity model from [Ribas et al. 2005](https://iopscience.iop.org/article/10.1086/427977) (R05)
#
# \begin{align}
# \frac{L_\mathrm{XUV}}{L_\mathrm{bol}} = \left\{
# 				\begin{array}{lcr}
# 					f_\mathrm{sat} &\ & t \leq t_\mathrm{sat} \\
# 					f_\mathrm{sat}\left(\frac{t}{t_\mathrm{sat}}\right)^{-\beta_\mathrm{XUV}} &\ & t > t_\mathrm{sat}
# 				\end{array}
# 				\right.,
# \end{align}
#
# where
#
# $L_\mathrm{XUV} / L_\mathrm{bol}$ is the ratio of X-ray luminosity to bolometric (total) luminosity
#
# $f_{sat}$ is the constant ratio of stellar XUV to bolometric luminosity during the saturated phase
#
# $t_{sat}$ is the duration of the saturated phase
#
# $\beta_{XUV}$ is the exponent that controls how steeply $L_{\rm XUV}$ decays after saturation

# %% [markdown]
# ### XUV luminosity model from [Johnstone et al. 2021](https://arxiv.org/abs/2009.07695) (J21)
#
# \begin{equation}
#     \frac{L_\mathrm{X}}{L_\mathrm{bol}} = \left \{
#     \begin{array}{ll}
#     C_1 Ro^{\beta_1}, & \text{if }  Ro \ge Ro_\mathrm{sat},\\
#     C_2 Ro^{\beta_2}, & \text{if }  Ro \le Ro_\mathrm{sat},\\
#     \end{array} \right.
# \end{equation}
#
# where
#
# $L_\mathrm{X} / L_\mathrm{bol}$ is the ratio of X-ray luminosity to bolometric (total) luminosity
#
# $R_o$ is the Rossby number (the rotation period / convective turnover timescale of the star)
#
# $C_1$, $C_2$, $\beta_1$, and $\beta_2$ are constants
#
# ### Best fit values from the paper:
#
# $\beta_1 = -0.135 \pm 0.030$
#
# $\beta_2 = -1.889 \pm 0.079$
#
# $Ro_\mathrm{sat} = 0.0605 \pm 0.00331$
#
# $R_\mathrm{X,sat} = 5.135 \times 10^{-4} \pm 3.320 \times 10^{-5}$
#
# $R_\mathrm{X,sat}$ is the value of $R_\mathrm{X}$ at $Ro_\mathrm{sat}$
# and the constants $C_1$, $C_2$ can be solved for using the relation:
# $R_\mathrm{X,sat} = C_1 Ro_\mathrm{sat}^{\alpha_1} = C_2 Ro_\mathrm{sat}^{\alpha_2}$
#
# Why we will use the Johnstone 2021 model:
# - model parameters are not dependent on stellar mass
# - constants have been empirically calibrated from a large sample of FGKM dwarfs (see Figure 4 of the paper)
#
# ![johnstone_fig4.png](attachment:johnstone_fig4.png)

# %%
# To run implement the Johnstone model, we will define the mean and uncertainty for the model parameters

j21 = {"beta1": (-0.135, 0.030),
       "beta2": (-1.889, 0.079),
       "Rosat": (0.0605, 0.00331),
       "RXsat": (5.135e-4, 3.320e-5)}

# %%
# Initialize the vplanet model with the input and output parameters

inpath = "../infiles/stellar/"
outpath = "output/"

inparams = {"star.dMass": u.Msun,
            "star.dRotPeriod": u.days,
            "vpl.dStopTime": u.Gyr}

outparams = {"final.star.Luminosity": u.Lsun,
             "final.star.RotPer": u.days,
             "final.star.RossbyNumber": u.dimensionless_unscaled}

vpm = vpi.VplanetModel(inparams=inparams,
                       outparams=outparams,
                       inpath=inpath,
                       outpath=outpath,
                       time_init=5e6*u.yr,
                       timesteps=1e6*u.yr,
                       verbose=True)

# %%
# Implement the additional equations needed for the Johnstone XUV luminosity model

def LXUV_model(mstar, prot, age, beta1, beta2, Rosat, RXsat):

    evol = vpm.run_model(np.array([mstar, prot, age]), remove=True)
    ross = evol["final.star.RossbyNumber"]
    lbol = evol["final.star.Luminosity"]

    C1 = RXsat / Rosat**beta1
    C2 = RXsat / Rosat**beta2
    
    rx = np.zeros(len(ross))
    for ii in range(len(ross)):
        if ross[ii] < Rosat:
            rx[ii] = C1 * ross[ii]**beta1
        else:
            rx[ii] = C2 * ross[ii]**beta2

    evol["final.star.RX"] = rx
    evol["final.star.LXUV"] = rx * lbol

    return evol

# %% [markdown]
# Test the Johnstone model for a single star with $M_* = 1\, M_{\odot}$, initial $P_{\rm rot} = 0.5$ days, $t_{\rm age} = 9$ Gyr, and constants ($\beta_1$, $\beta_2$, $Ro_\mathrm{sat}$, $R_\mathrm{X,sat}$) from the J21 paper:

# %%
# inputs: theta = [mstar, prot, age, beta1, beta2, Rosat, RXsat]

theta = np.array([1.0, 0.5, 9.0, j21["beta1"][0], j21["beta2"][0], j21["Rosat"][0], j21["RXsat"][0]])
evol = LXUV_model(*theta)
# Out:
# Input:
# -----------------
# star.dMass : 1.0 [solMass] (user)   --->   1.988409870698051e+30 [kg] (vpl file)
# star.dRotPeriod : 0.5 [days] (user)   --->   43200.0 [s] (vpl file)
# vpl.dStopTime : 9.0 [Gyr] (user)   --->   2.840184e+17 [s] (vpl file)
#
# Created file output//141156668606994/vpl.in
# Created file output//141156668606994/star.in
# Executed model output//141156668606994/vpl.in 9.197 s
#
# Output:
# -----------------
# final.star.Luminosity : 1.46994644723093 [solLum]
# final.star.RossbyNumber : 3.667143 []
# final.star.RotPer : 47.50030092592592 [days]

# %%
def plot_evolution(evols, title="Johnstone 2021"):

    fig, axs = plt.subplots(3, 1, figsize=[10,14], sharex=True)

    for evol in evols:
        lbol = evol["final.star.Luminosity"].to(u.erg/u.s)
        lxuv = evol["final.star.LXUV"].to(u.erg/u.s)
        prot = evol["final.star.RotPer"]

        axs[0].plot(evol["Time"], lbol, color="k", alpha=0.5)
        axs[1].plot(evol["Time"], lxuv, color="k", alpha=0.5)
        axs[2].plot(evol["Time"], prot, color="k", alpha=0.5)

    axs[0].set_title(title, fontsize=24)
    axs[0].set_ylabel("Bolometric Luminosity [{}]".format(lbol.unit), fontsize=20)
    axs[0].set_xscale('log')
    axs[0].set_yscale('log')

    axs[1].set_ylabel("X-ray Luminosity [{}]".format(lxuv.unit), fontsize=20)
    axs[1].set_xscale('log')
    axs[1].set_yscale('log')

    axs[2].set_ylabel("Rotation Period [{}]".format(prot.unit), fontsize=20)
    axs[2].set_xlabel("Time [yr]", fontsize=20)
    axs[2].set_xscale('log')
    axs[2].set_yscale('log')

    axs[0].set_xlim(min(evol["Time"].value), max(evol["Time"].value))
    plt.tight_layout()
    
    return fig

# %%
plot_evolution([evol]);

# note that the input to the plot_evolution function is a list of dictionaries, where each dictionary is the output of the LXUV_model function
# since evol is a single dictionary, we add brackets around it to make it a list
# Out:
# /tmp/ipykernel_609661/1558624661.py:28: UserWarning: Attempted to set non-positive left xlim on a log-scaled axis.
# Invalid limit will be ignored.
#   axs[0].set_xlim(min(evol["Time"].value), max(evol["Time"].value))

# %% [markdown]
# ### Parameter sweep
#
# Let's try sampling a range of different plausible models for Trappist-1, given the known parameters and uncertainties

# %%
# Trappist-1

nsamp = 20
mass_samp = np.random.normal(0.089, 0.007, nsamp)
prot_samp = np.random.uniform(0.01, 5.0, nsamp)
age_samp = np.ones(nsamp) * 9.0
beta1_samp = np.random.normal(j21["beta1"][0], j21["beta1"][1], nsamp)
beta2_samp = np.random.normal(j21["beta2"][0], j21["beta2"][1], nsamp)
Rosat_samp = np.random.normal(j21["Rosat"][0], j21["Rosat"][1], nsamp)
RXsat_samp = np.random.normal(j21["RXsat"][0], j21["RXsat"][1], nsamp)

thetas = np.array([mass_samp, prot_samp, age_samp, beta1_samp, beta2_samp, Rosat_samp, RXsat_samp]).T

# Run with multiple cores
ncores = mp.cpu_count()
print("number of cores available:", ncores)
with mp.Pool(ncores) as pool:
    evols = pool.starmap(LXUV_model, thetas)

# If multiple cores does not work, comment out the previous two lines and uncomment the following lines 
# evols = []
# for ii in range(nsamp):
#     evols.append(LXUV_model(*thetas[ii]))
# Out:
# number of cores available: 16
#
# Input:
# Input:
# Input:
# Input:
# Input:
# Input:
# Input:
# Input:
# Input:
# Input:
# Input:
# Input:
# Input:
# Input:
#
# Input:
#
#
#
#
#
#
#
#
#
#
# Input:
#
# -----------------
# -----------------
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# ----------------------------------
# -----------------
#
#
#
#
#
#
#
#
#
# -----------------
#
# star.dMass : 0.08767143835826308 [solMass] (user)   --->   1.7432675340986602e+29 [kg] (vpl file)star.dMass : 0.08709127885737568 [solMass] (user)   --->   1.7317315853172227e+29 [kg] (vpl file)
# star.dMass : 0.08388079997767403 [solMass] (user)   --->   1.667894106376559e+29 [kg] (vpl file)star.dMass : 0.09279718153319663 [solMass] (user)   --->   1.845188317335671e+29 [kg] (vpl file)star.dMass : 0.08027781347614313 [solMass] (user)   --->   1.5962519671402e+29 [kg] (vpl file)star.dMass : 0.0839447387666068 [solMass] (user)   --->   1.669165471566903e+29 [kg] (vpl file)star.dMass : 0.09350331082840299 [solMass] (user)   --->   1.8592290619414445e+29 [kg] (vpl file)star.dMass : 0.08382514842145021 [solMass] (user)   --->   1.6667875253394073e+29 [kg] (vpl file)star.dMass : 0.09181875219848391 [solMass] (user)   --->   1.825733131866438e+29 [kg] (vpl file)
# star.dMass : 0.0888974906170114 [solMass] (user)   --->   1.7676464782315283e+29 [kg] (vpl file)star.dMass : 0.08612698873639739 [solMass] (user)   --->   1.7125575453695244e+29 [kg] (vpl file)
# star.dMass : 0.08364204177877095 [solMass] (user)   --->   1.6631466147824693e+29 [kg] (vpl file)star.dMass : 0.08399117846965783 [solMass] (user)   --->   1.6700888832062925e+29 [kg] (vpl file)
#
#
# star.dMass : 0.09302435385182095 [solMass] (user)   --->   1.8497054341426903e+29 [kg] (vpl file)
#
# star.dMass : 0.08326735891397086 [solMass] (user)   --->   1.65569638371497e+29 [kg] (vpl file)
#
#
# star.dMass : 0.09687433602238223 [solMass] (user)   --->   1.926258859642246e+29 [kg] (vpl file)
#
#
# star.dRotPeriod : 2.9074321758840127 [days] (user)   --->   251202.1399963787 [s] (vpl file)star.dRotPeriod : 3.4197513664467563 [days] (user)   --->   295466.51806099975 [s] (vpl file)
# star.dRotPeriod : 1.619389964645721 [days] (user)   --->   139915.2929453903 [s] (vpl file)
# star.dRotPeriod : 4.818655448340017 [days] (user)   --->   416331.8307365775 [s] (vpl file)
# star.dRotPeriod : 3.976556541272616 [days] (user)   --->   343574.48516595404 [s] (vpl file)star.dRotPeriod : 0.4563023208490455 [days] (user)   --->   39424.52052135753 [s] (vpl file)star.dRotPeriod : 1.6930748674588278 [days] (user)   --->   146281.6685484427 [s] (vpl file)star.dRotPeriod : 1.855139106774439 [days] (user)   --->   160284.01882531153 [s] (vpl file)
# star.dRotPeriod : 4.577871115212028 [days] (user)   --->   395528.06435431924 [s] (vpl file)star.dRotPeriod : 3.0084316938391837 [days] (user)   --->   259928.49834770546 [s] (vpl file)
# star.dRotPeriod : 0.8726417643026778 [days] (user)   --->   75396.24843575136 [s] (vpl file)star.dRotPeriod : 3.501492121657424 [days] (user)   --->   302528.91931120143 [s] (vpl file)star.dRotPeriod : 4.830333744610645 [days] (user)   --->   417340.8355343597 [s] (vpl file)
#
# star.dRotPeriod : 1.5004126773421662 [days] (user)   --->   129635.65532236316 [s] (vpl file)
# star.dRotPeriod : 0.6966186421324668 [days] (user)   --->   60187.85068024513 [s] (vpl file)
#
#
#
# star.dRotPeriod : 3.601227553123191 [days] (user)   --->   311146.0605898437 [s] (vpl file)
#
#
#
# vpl.dStopTime : 9.0 [Gyr] (user)   --->   2.840184e+17 [s] (vpl file)
#
# vpl.dStopTime : 9.0 [Gyr] (user)   --->   2.840184e+17 [s] (vpl file)vpl.dStopTime : 9.0 [Gyr] (user)   --->   2.840184e+17 [s] (vpl file)vpl.dStopTime : 9.0 [Gyr] (user)   --->   2.840184e+17 [s] (vpl file)vpl.dStopTime : 9.0 [Gyr] (user)   --->   2.840184e+17 [s] (vpl file)
# vpl.dStopTime : 9.0 [Gyr] (user)   --->   2.840184e+17 [s] (vpl file)vpl.dStopTime : 9.0 [Gyr] (user)   --->   2.840184e+17 [s] (vpl file)vpl.dStopTime : 9.0 [Gyr] (user)   --->   2.840184e+17 [s] (vpl file)
# vpl.dStopTime : 9.0 [Gyr] (user)   --->   2.840184e+17 [s] (vpl file)vpl.dStopTime : 9.0 [Gyr] (user)   --->   2.840184e+17 [s] (vpl file)vpl.dStopTime : 9.0 [Gyr] (user)   --->   2.840184e+17 [s] (vpl file)vpl.dStopTime : 9.0 [Gyr] (user)   --->   2.840184e+17 [s] (vpl file)
# vpl.dStopTime : 9.0 [Gyr] (user)   --->   2.840184e+17 [s] (vpl file)
#
#
# vpl.dStopTime : 9.0 [Gyr] (user)   --->   2.840184e+17 [s] (vpl file)vpl.dStopTime : 9.0 [Gyr] (user)   --->   2.840184e+17 [s] (vpl file)
#
#
# vpl.dStopTime : 9.0 [Gyr] (user)   --->   2.840184e+17 [s] (vpl file)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Created file output//206580986453823/vpl.in
# Created file output//31131438013737/vpl.inCreated file output//28337992057556/vpl.in
# Created file output//104915597687213/vpl.inCreated file output//227554425016149/vpl.inCreated file output//158937510009199/vpl.inCreated file output//380163196191/vpl.inCreated file output//234605457704699/vpl.inCreated file output//201526762747379/vpl.inCreated file output//188950380897263/vpl.inCreated file output//210732965276367/vpl.in
# Created file output//240149328592857/vpl.inCreated file output//44853472616533/vpl.in
# Created file output//224949058027985/vpl.inCreated file output//244166589336415/vpl.inCreated file output//6780069020005/vpl.in
#
#
#
# Created file output//206580986453823/star.in
# Created file output//31131438013737/star.in
#
#
#
#
#
#
#
# Created file output//158937510009199/star.in
#
# Created file output//28337992057556/star.inCreated file output//380163196191/star.inCreated file output//227554425016149/star.inCreated file output//104915597687213/star.inCreated file output//44853472616533/star.in
# Created file output//234605457704699/star.inCreated file output//210732965276367/star.inCreated file output//6780069020005/star.inCreated file output//240149328592857/star.inCreated file output//201526762747379/star.inCreated file output//188950380897263/star.in
#
#
#
#
#
#
# Created file output//224949058027985/star.in
#
# Created file output//244166589336415/star.in
#
#
#
#
# Executed model output//234605457704699/vpl.in 16.931 s
#
# Output:
# -----------------
# final.star.Luminosity : 0.0006737385057471265 [solLum]
# final.star.RossbyNumber : 0.630324 []
# final.star.RotPer : 49.24305555555555 [days]
#
#
# Input:
# -----------------
# star.dMass : 0.07957496479203527 [solMass] (user)   --->   1.582276454529328e+29 [kg] (vpl file)
# star.dRotPeriod : 1.8258451629759396 [days] (user)   --->   157753.0220811212 [s] (vpl file)
# vpl.dStopTime : 9.0 [Gyr] (user)   --->   2.840184e+17 [s] (vpl file)
#
# Created file output//215778654628436/vpl.in
# Created file output//215778654628436/star.in
# Executed model output//6780069020005/vpl.in 17.781 s
#
# Output:
# -----------------
# final.star.Luminosity : 0.0007766212121212121 [solLum]
# final.star.RossbyNumber : 0.785456 []
# final.star.RotPer : 59.753865740740736 [days]
#
# Executed model output//188950380897263/vpl.in 18.376 s
#
# Output:
# -----------------
# final.star.Luminosity : 0.0006205906478578893 [solLum]
# final.star.RossbyNumber : 0.712133 []
# final.star.RotPer : 56.54020833333333 [days]
#
#
# Input:
# -----------------
# star.dMass : 0.09093818915933517 [solMass] (user)   --->   1.8082239294782856e+29 [kg] (vpl file)
# star.dRotPeriod : 2.9141322728613237 [days] (user)   --->   251781.02837521836 [s] (vpl file)
# vpl.dStopTime : 9.0 [Gyr] (user)   --->   2.840184e+17 [s] (vpl file)
#
# Created file output//272923157504613/vpl.in
# Created file output//272923157504613/star.in
#
# Input:
# -----------------
# star.dMass : 0.09260867868836803 [solMass] (user)   --->   1.8414401081625524e+29 [kg] (vpl file)
# star.dRotPeriod : 2.0171002072815685 [days] (user)   --->   174277.45790912752 [s] (vpl file)
# vpl.dStopTime : 9.0 [Gyr] (user)   --->   2.840184e+17 [s] (vpl file)
#
# Created file output//115201720577115/vpl.in
# Created file output//115201720577115/star.in
# Executed model output//28337992057556/vpl.in 20.536 s
#
# Output:
# -----------------
# final.star.Luminosity : 0.000651673197492163 [solLum]
# final.star.RossbyNumber : 0.771693 []
# final.star.RotPer : 60.67884259259259 [days]
#
# Executed model output//227554425016149/vpl.in 21.146 s
#
# Output:
# -----------------
# final.star.Luminosity : 0.00046161102403343785 [solLum]
# final.star.RossbyNumber : 0.676262 []
# final.star.RotPer : 57.06262731481481 [days]
#
#
# Input:
# -----------------
# star.dMass : 0.07514710578388303 [solMass] (user)   --->   1.4942324689506362e+29 [kg] (vpl file)
# star.dRotPeriod : 0.5542712380785091 [days] (user)   --->   47889.034969983186 [s] (vpl file)
# vpl.dStopTime : 9.0 [Gyr] (user)   --->   2.840184e+17 [s] (vpl file)
#
# Created file output//27317873448217/vpl.in
# Created file output//27317873448217/star.in
# Executed model output//210732965276367/vpl.in 22.896 s
#
# Output:
# -----------------
# final.star.Luminosity : 0.0006588032915360501 [solLum]
# final.star.RossbyNumber : 0.711017 []
# final.star.RotPer : 55.789085648148145 [days]
#
# Executed model output//206580986453823/vpl.in 23.083 s
#
# Output:
# -----------------
# final.star.Luminosity : 0.0004814041274817137 [solLum]
# final.star.RossbyNumber : 0.730877 []
# final.star.RotPer : 61.13942129629629 [days]
#
# Executed model output//244166589336415/vpl.in 23.891 s
#
# Output:
# -----------------
# final.star.Luminosity : 0.00052364289446186 [solLum]
# final.star.RossbyNumber : 0.741163 []
# final.star.RotPer : 60.93237268518518 [days]
#
# Executed model output//201526762747379/vpl.in 24.358 s
#
# Output:
# -----------------
# final.star.Luminosity : 0.00042944618599791016 [solLum]
# final.star.RossbyNumber : 0.741162 []
# final.star.RotPer : 63.476273148148145 [days]
#
# Executed model output//380163196191/vpl.in 25.431 s
#
# Output:
# -----------------
# final.star.Luminosity : 0.0003535005224660397 [solLum]
# final.star.RossbyNumber : 0.690147 []
# final.star.RotPer : 61.527812499999996 [days]
#
# Executed model output//44853472616533/vpl.in 26.116 s
#
# Output:
# -----------------
# final.star.Luminosity : 0.00035867633228840127 [solLum]
# final.star.RossbyNumber : 0.657895 []
# final.star.RotPer : 58.47643518518518 [days]
#
# Executed model output//104915597687213/vpl.in 27.244 s
#
# Output:
# -----------------
# final.star.Luminosity : 0.000363432079414838 [solLum]
# final.star.RossbyNumber : 0.603064 []
# final.star.RotPer : 53.45696759259259 [days]
#
# Executed model output//240149328592857/vpl.in 28.164 s
#
# Output:
# -----------------
# final.star.Luminosity : 0.00036209613375130616 [solLum]
# final.star.RossbyNumber : 0.720539 []
# final.star.RotPer : 63.91899305555555 [days]
#
# Executed model output//31131438013737/vpl.in 28.337 s
#
# Output:
# -----------------
# final.star.Luminosity : 0.00036026384535005226 [solLum]
# final.star.RossbyNumber : 0.689682 []
# final.star.RotPer : 61.24590277777777 [days]
#
# Executed model output//224949058027985/vpl.in 28.816 s
#
# Output:
# -----------------
# final.star.Luminosity : 0.0003431405433646813 [solLum]
# final.star.RossbyNumber : 0.578357 []
# final.star.RotPer : 51.87996527777778 [days]
#
# Executed model output//158937510009199/vpl.in 29.677 s
#
# Output:
# -----------------
# final.star.Luminosity : 0.0002722008881922675 [solLum]
# final.star.RossbyNumber : 0.698744 []
# final.star.RotPer : 65.7974074074074 [days]
#
# Executed model output//272923157504613/vpl.in 15.738 s
#
# Output:
# -----------------
# final.star.Luminosity : 0.0005920655694879833 [solLum]
# final.star.RossbyNumber : 0.742135 []
# final.star.RotPer : 59.48491898148148 [days]
#
# Executed model output//115201720577115/vpl.in 15.352 s
#
# Output:
# -----------------
# final.star.Luminosity : 0.0006457327586206896 [solLum]
# final.star.RossbyNumber : 0.728053 []
# final.star.RotPer : 57.35041666666666 [days]
#
# Executed model output//215778654628436/vpl.in 20.433 s
#
# Output:
# -----------------
# final.star.Luminosity : 0.00025046752873563214 [solLum]
# final.star.RossbyNumber : 0.621677 []
# final.star.RotPer : 59.595613425925926 [days]
#
# Executed model output//27317873448217/vpl.in 19.625 s
#
# Output:
# -----------------
# final.star.Luminosity : 0.0001321492424242424 [solLum]
# final.star.RossbyNumber : 0.466719 []
# final.star.RotPer : 51.45387731481481 [days]

# %% [markdown]
# Next, let's plot the models we just ran and see how the evolution models (black lines) compare to the observational data (red lines) of the system at present day
# using data from [https://jbirky.github.io/yupra/docs/datasets.html](https://jbirky.github.io/yupra/docs/datasets.html)
#
# Note: make sure that the units are consistent with those in the data table.
#
# Then plot the observational constraints and uncertainties on top of the models, to compare how well the models match the data.

# %%
# data = [mean, lower error, upper error]

Lbol_data = np.array([5.22e-4, -0.19e-4, 0.19e-4]) * u.Lsun
Lbol_data = Lbol_data.to(u.erg/u.s).value

Lxuv_data = np.array([1.0e-4, -0.1e-4, 0.1e-4]) * Lbol_data * u.Lsun
Lxuv_data = Lxuv_data.value

Prot_data = np.array([3.295, -0.003, 0.003]) * u.day
Prot_data = Prot_data.value

age_data = np.array([7.6, -2.2, 2.2]) * u.Gyr
age_data = age_data.to(u.yr).value

# %%
fig = plot_evolution(evols, title="Trappist-1 model samples")
axs = fig.axes

axs[0].axhline(Lbol_data[0], color="r", linestyle="--")
axs[0].axhspan(Lbol_data[0]+Lbol_data[1], Lbol_data[0]+Lbol_data[2], color="r", alpha=0.2)

axs[1].axhline(Lxuv_data[0], color="r", linestyle="--")
axs[1].axhspan(Lxuv_data[0]+Lxuv_data[1], Lxuv_data[0]+Lxuv_data[2], color="r", alpha=0.2)

axs[2].axhline(Prot_data[0], color="r", linestyle="--")
axs[2].axhspan(Prot_data[0]+Prot_data[1], Prot_data[0]+Prot_data[2], color="r", alpha=0.2)

for ii in range(len(axs)):
    axs[ii].axvline(age_data[0], color="r", linestyle="--")
    axs[ii].axvspan(age_data[0]+age_data[1], age_data[0]+age_data[2], color="r", alpha=0.2)

fig.show()
# Out:
# /tmp/ipykernel_609661/1558624661.py:28: UserWarning: Attempted to set non-positive left xlim on a log-scaled axis.
# Invalid limit will be ignored.
#   axs[0].set_xlim(min(evol["Time"].value), max(evol["Time"].value))
# /tmp/ipykernel_609661/1055320492.py:17: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# Note: for the Trappist system, the constraints on rotation period and xray luminosity suggest a younger age (~1-3 Gyr, based on where the models intersect the horizontal red lines) than what is reported in literature ($7.6\pm2.2$ Gyr, from Burgasser and Mamajek 2017). However, age is one of the most difficult parameters to reliably measure for a star, so it is not too surprising that the literature age is inconsistent.
